# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/rammaruthi/Desktop/AI TRAINING/Datasets/decissionTree-data.csv')

# %%
df
# Out:
#        X    Y
# 0     60  180
# 1     70  180
# 2     80  200
# 3    100  200
# 4    120  200
# 5    150  220
# 6    200  240
# 7    250  240
# 8    300  300
# 9    400  350
# 10   500  350
# 11   750  360
# 12  1000  365
# 13  2000  365
# 14  3000  365

# %%
X =  df.drop('Y',axis=1)
X
# Out:
#        X
# 0     60
# 1     70
# 2     80
# 3    100
# 4    120
# 5    150
# 6    200
# 7    250
# 8    300
# 9    400
# 10   500
# 11   750
# 12  1000
# 13  2000
# 14  3000

# %%
Y = df.drop('X',axis=1)

# %%
plt.scatter(X,Y)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()
model.fit(X,Y)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(X)

# %%
y_pred
# Out:
# array([180., 180., 200., 200., 200., 220., 240., 240., 300., 350., 350.,
#        360., 365., 365., 365.])

# %%
Y
# Out:
#       Y
# 0   180
# 1   180
# 2   200
# 3   200
# 4   200
# 5   220
# 6   240
# 7   240
# 8   300
# 9   350
# 10  350
# 11  360
# 12  365
# 13  365
# 14  365

# %%
from sklearn.metrics import accuracy_score

# %%
plt.scatter(X,Y)
plt.plot(X,y_pred)
