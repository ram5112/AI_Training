# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/rammaruthi/Desktop/AI TRAINING/Datasets/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0          86    2790          15.6
# 388  44.0          4          97.0          52    2130          24.6
# 389  32.0          4         135.0          84    2295          11.6
# 390  28.0          4         120.0          79    2625          18.6
# 391  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
X = df.drop(['mpg','car name'],axis = 1)
y = df[['mpg']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()

# %%
X_train_transform = scale.fit_transform(X_train)
X_test_transform = scale.fit_transform(X_test)

# %%
X_train
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 200          6         258.0          95    3193          17.8          76
# 182          4         140.0          92    2572          14.9          76
# 3            8         304.0         150    3433          12.0          70
# 174          6         232.0          90    3211          17.0          75
# 259          6         258.0         120    3410          15.1          78
# ..         ...           ...         ...     ...           ...         ...
# 299          4         105.0          70    2200          13.2          79
# 22           4         104.0          95    2375          17.5          70
# 72           8         307.0         130    4098          14.0          72
# 15           6         198.0          95    2833          15.5          70
# 168          4         140.0          78    2592          18.5          75
#
#      origin
# 200       1
# 182       1
# 3         1
# 174       1
# ...

# %%
X_train_transform
# Out:
# array([[0.6       , 0.49095607, 0.26630435, ..., 0.58333333, 0.5       ,
#         0.        ],
#        [0.2       , 0.18604651, 0.25      , ..., 0.41071429, 0.5       ,
#         0.        ],
#        [1.        , 0.60981912, 0.56521739, ..., 0.23809524, 0.        ,
#         0.        ],
#        ...,
#        [1.        , 0.61757106, 0.45652174, ..., 0.35714286, 0.16666667,
#         0.        ],
#        [0.6       , 0.33591731, 0.26630435, ..., 0.44642857, 0.        ,
#         0.        ],
#        [0.2       , 0.18604651, 0.17391304, ..., 0.625     , 0.41666667,
#         0.        ]])

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_transform,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_transform)

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
score
# Out:
# 0.7705489596400993

# %%
from sklearn.linear_model import Lasso

# %%
lassoModel = Lasso(alpha=0.5)

# %%
lassoModel.fit(X_train_transform,y_train)
# Out:
# Lasso(alpha=0.5)

# %%
y_train_pred = lassoModel.predict(X_train_transform)
y_test_pred = lassoModel.predict(X_test_transform)

# %%
from sklearn.metrics import r2_score
lassoScore = r2_score(y_test,y_test_pred)

# %%
lassoScore
# Out:
# 0.6867133207146686

# %%
print(lassoModel.coef_)
# Out:
# [-6.94382849 -0.         -0.         -5.27357558  0.          5.20542724
#   2.28912857]
